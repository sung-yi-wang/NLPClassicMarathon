# %%
## Yahoo新聞
#https://tw.news.yahoo.com/omicron%E5%A4%A7%E7%88%86%E7%99%BC%E6%89%9B%E4%B8%8D%E4%BD%8F-%E5%8D%97%E9%9F%93%E5%AE%A3%E5%B8%83%E6%94%BE%E6%A3%84%E6%AA%A2%E6%B8%AC-%E8%BF%BD%E8%B9%A4%E8%BC%95%E7%97%87%E8%80%85-232554989.html

# %%
text = """Omicron大爆發扛不住 南韓宣布放棄檢測、追蹤輕症者
變種病毒Omicron傳染力極高，現在是大多數國家的主要流行病毒株，並大量肆虐中，先前靠著優秀的大規模檢測及積極主動追蹤，將疫情控制得宜的南韓也不敵Omicron，近半個月來每日確診數都破萬，讓衛生官員不堪負荷，政府也在7日宣布放棄檢測及追蹤輕症患者，更改防疫策略。
日、韓疫情燒不完，其中韓國自1月25日以來確診數日日破萬，且沒有減緩趨勢。美聯社報導，韓國疾管局報告指出，國內本週出現3萬8,691起新案，比1月中旬暴增9倍，感染的多為Omicron病毒株，並推測到了2月下旬，每日新增感染者可能多達13萬至17萬人。
而韓國自2020新冠肺炎疫情爆發起，衛生局與生技公司合作，不但加強實驗室的檢測量能、利用新技術追蹤可能接觸者儘早隔離，更透過智慧型手機GPS定位功能進行監測，派駐醫療人員前往患者住處進行治療，疫情也因此控制得宜。
不過由於Omicron傳染力太過強大，確診者激增，衛生人員不堪負荷，也耗盡了衛生及行政資源，韓國政府宣布放棄檢測及追蹤，改變防疫策略為60歲以下低風險輕症患者自行監測健康狀況，症狀惡化時再聯繫當地醫院；60歲以上的較高風險患者則持續由衛生單位監控、醫療人員到府檢查，希望能將醫療資源留給重症患者。
"""
text
# Out:
# 'Omicron大爆發扛不住 南韓宣布放棄檢測、追蹤輕症者\n變種病毒Omicron傳染力極高，現在是大多數國家的主要流行病毒株，並大量肆虐中，先前靠著優秀的大規模檢測及積極主動追蹤，將疫情控制得宜的南韓也不敵Omicron，近半個月來每日確診數都破萬，讓衛生官員不堪負荷，政府也在7日宣布放棄檢測及追蹤輕症患者，更改防疫策略。\n日、韓疫情燒不完，其中韓國自1月25日以來確診數日日破萬，且沒有減緩趨勢。美聯社報導，韓國疾管局報告指出，國內本週出現3萬8,691起新案，比1月中旬暴增9倍，感染的多為Omicron病毒株，並推測到了2月下旬，每日新增感染者可能多達13萬至17萬人。\n而韓國自2020新冠肺炎疫情爆發起，衛生局與生技公司合作，不但加強實驗室的檢測量能、利用新技術追蹤可能接觸者儘早隔離，更透過智慧型手機GPS定位功能進行監測，派駐醫療人員前往患者住處進行治療，疫情也因此控制得宜。\n不過由於Omicron傳染力太過強大，確診者激增，衛生人員不堪負荷，也耗盡了衛生及行政資源，韓國政府宣布放棄檢測及追蹤，改變防疫策略為60歲以下低風險輕症患者自行監測健康狀況，症狀惡化時再聯繫當地醫院；60歲以上的較高風險患者則持續由衛生單位監控、醫療人員到府檢查，希望能將醫療資源留給重症患者。\n'

# %% [markdown]
# # Q1: 請先去除換行符號，並使用SnowNLP或HaNLP斷詞。

# %%
from snownlp import SnowNLP
s_t = SnowNLP(text)
print(s_t.words)
# Out:
# ['Omicron', '大', '爆', '發', '扛', '不', '住', '南', '韓', '宣', '布', '放', '棄', '檢', '測', '、', '追', '蹤', '輕症', '者', '變', '種', '病毒', 'Omicron', '傳', '染力', '極', '高', '，', '現', '在', '是', '大', '多', '數', '國家', '的', '主要', '流行', '病毒', '株', '，', '並', '大量', '肆虐', '中', '，', '先前', '靠', '著', '優秀', '的', '大', '規', '模', '檢', '測', '及', '積', '極', '主', '動', '追', '蹤', '，', '將', '疫情', '控制', '得宜', '的', '南', '韓', '也', '不', '敵', 'Omicron，', '近', '半', '個月', '來', '每', '日', '確', '診', '數', '都破', '萬', '，', '讓', '衛', '生', '官', '員', '不', '堪', '負', '荷', '，', '政府', '也', '在', '7', '日', '宣', '布', '放', '棄', '檢', '測', '及', '追', '蹤', '輕症', '患者', '，', '更改', '防疫', '策略', '。', '日', '、', '韓', '疫', '情', '燒', '不', '完', '，', '其', '中', '韓', '國', '自', '1', '月', '25', '日', '以', '來', '確', '診', '數日', '日破', '萬', '，', '且', '沒', '有', '減', '緩', '趨', '勢', '。', '美', '聯', '社', '報', '導', '，', '韓', '國', '疾', '管局', '報告', '指出', '，', '國', '內', '本', '週出', '現', '3', '萬', '8,691', '起', '新案', '，', '比', '1', '月', '中旬', '暴', '增', '9', '倍', '，', '感染', '的', '多', '為', 'Omicron', '病毒', '株', '，', '並', '推', '測到', '了', '2', '月', '下旬', '，', '每日', '新增', '感染者', '可', '能', '多', '達', '13', '萬', '至', '17', '萬', '人', '。', '而', '韓', '國', '自', '2020', '新', '冠', '肺炎', '疫', '情', '爆', '發', '起', '，', '衛', '生局', '與', '生技', '公司', '合作', '，', '不', '但', '加', '強', '實', '驗', '室', '的', '檢', '測量', '能', '、', '利用', '新', '技', '術', '追', '蹤', '可', '能', '接', '觸者', '儘', '早', '隔', '離', '，', '更', '透', '過', '智慧', '型手', '機', 'GPS', '定位', '功', '能', '進', '行', '監', '測', '，', '派', '駐', '醫', '療', '人', '員', '前往', '患', '者', '住', '處', '進', '行治', '療', '，', '疫情', '也', '因此', '控制', '得宜', '。', '不', '過', '由', '於', 'Omicron', '傳染', '力', '太', '過', '強', '大', '，', '確', '診者', '激增', '，', '衛', '生', '人', '員', '不', '堪', '負', '荷', '，', '也耗', '盡', '了', '衛生', '及', '行', '政', '資源', '，', '韓', '國', '政府', '宣', '布', '放', '棄', '檢', '測', '及', '追', '蹤', '，', '改', '變防疫', '策略', '為', '60', '歲以', '下', '低', '風', '險', '輕症', '患者', '自', '行', '監', '測', '健', '康', '狀', '況', '，', '症', '狀', '惡化', '時', '再', '聯', '繫', '當', '地', '醫院', '；60', '歲', '以', '上', '的', '較', '高', '風', '險', '患者', '則持', '續', '由', '衛', '生', '單位', '監', '控', '、', '醫', '療', '人', '員', '到府', '檢查', '，', '希', '望', '能', '將', '醫', '療', '資', '源', '留', '給', '重症', '患者', '。']

# %% [markdown]
# # Q2:請使用SnowNLP或HaNLP 進行詞性標記(POS Tagging)。

# %%
print(list(s_t.tags))
# Out:
# [('Omicron', 'Dg'), ('大', 'a'), ('爆', 'v'), ('發', 'Ag'), ('扛', 'v'), ('不', 'd'), ('住', 'v'), ('南', 'j'), ('韓', 'j'), ('宣', 'nr'), ('布', 'nr'), ('放', 'v'), ('棄', 'Rg'), ('檢', 'Rg'), ('測', 'Rg'), ('、', 'w'), ('追', 'v'), ('蹤', 'Rg'), ('輕症', 'Rg'), ('者', 'k'), ('變', 'Rg'), ('種', 'Rg'), ('病毒', 'n'), ('Omicron', 'Rg'), ('傳', 'Rg'), ('染力', 'Rg'), ('極', 'Rg'), ('高', 'Ng'), ('，', 'w'), ('現', 'Ag'), ('在', 'p'), ('是', 'v'), ('大', 'a'), ('多', 'm'), ('數', 'q'), ('國家', 'f'), ('的', 'u'), ('主要', 'b'), ('流行', 'vn'), ('病毒', 'n'), ('株', 'q'), ('，', 'w'), ('並', 'r'), ('大量', 'm'), ('肆虐', 'v'), ('中', 'f'), ('，', 'w'), ('先前', 't'), ('靠', 'v'), ('著', 'Vg'), ('優秀', 'Ag'), ('的', 'u'), ('大', 'a'), ('規', 'Ag'), ('模', 'Ng'), ('檢', 'Tg'), ('測', 'Tg'), ('及', 'c'), ('積', 'Tg'), ('極', 'Tg'), ('主', 'Vg'), ('動', 'Tg'), ('追', 'v'), ('蹤', 'Tg'), ('，', 'w'), ('將', 'Tg'), ('疫情', 'n'), ('控制', 'vn'), ('得宜', 'n'), ('的', 'u'), ('南', 'j'), ('韓', 'j'), ('也', 'd'), ('不', 'd'), ('敵', 'Ag'), ('Omicron，', 'Bg'), ('近', 'a'), ('半', 'm'), ('個月', 'Rg'), ('來', 'Rg'), ('每', 'r'), ('日', 'Ng'), ('確', 'o'), ('診', 'o'), ('數', 'o'), ('都破', 'e'), ('萬', 'e'), ('，', 'w'), ('讓', 'Rg'), ('衛', 'Rg'), ('生', 'Ng'), ('官', 'n'), ('員', 'nr'), ('不', 'd'), ('堪', 'Vg'), ('負', 'i'), ('荷', 'Ng'), ('，', 'w'), ('政府', 'n'), ('也', 'd'), ('在', 'p'), ('7', 'j'), ('日', 'j'), ('宣', 'nr'), ('布', 'nr'), ('放', 'v'), ('棄', 'Rg'), ('檢', 'Rg'), ('測', 'Rg'), ('及', 'c'), ('追', 'v'), ('蹤', 'Rg'), ('輕症', 'Rg'), ('患者', 'n'), ('，', 'w'), ('更改', 'v'), ('防疫', 'vn'), ('策略', 'n'), ('。', 'w'), ('日', 'Ng'), ('、', 'w'), ('韓', 'Ag'), ('疫', 'Bg'), ('情', 'n'), ('燒', 'c'), ('不', 'd'), ('完', 'v'), ('，', 'w'), ('其', 'r'), ('中', 'f'), ('韓', 'Rg'), ('國', 'Rg'), ('自', 'p'), ('1', 'vvn'), ('月', 'n'), ('25', 'm'), ('日', 'q'), ('以', 'p'), ('來', 'o'), ('確', 'o'), ('診', 'o'), ('數日', 'o'), ('日破', 'e'), ('萬', 'e'), ('，', 'w'), ('且', 'c'), ('沒', 'd'), ('有', 'v'), ('減', 'o'), ('緩', 'o'), ('趨', 'e'), ('勢', 'e'), ('。', 'w'), ('美', 'a'), ('聯', 'Ag'), ('社', 'Ng'), ('報', 'o'), ('導', 'o'), ('，', 'w'), ('韓', 'o'), ('國', 'o'), ('疾', 'o'), ('管局', 'e'), ('報告', 'e'), ('指出', 'v'), ('，', 'w'), ('國', 'Rg'), ('內', 'Rg'), ('本', 'd'), ('週出', 'o'), ('現', 'o'), ('3', 'o'), ('萬', 'e'), ('8,691', 'e'), ('起', 'v'), ('新案', 'y'), ('，', 'w'), ('比', 'p'), ('1', 'ns'), ('月', 'n'), ('中旬', 't'), ('暴', 'Tg'), ('增', 'v'), ('9', 'm'), ('倍', 'q'), ('，', 'w'), ('感染', 'v'), ('的', 'u'), ('多', 'm'), ('為', 'w'), ('Omicron', 'vvn'), ('病毒', 'n'), ('株', 'q'), ('，', 'w'), ('並', 'ad'), ('推', 'v'), ('測到', 'nx'), ('了', 'u'), ('2', 'nx'), ('月', 'n'), ('下旬', 't'), ('，', 'w'), ('每日', 'r'), ('新增', 'v'), ('感染者', 'n'), ('可', 'v'), ('能', 'v'), ('多', 'm'), ('達', 'Rg'), ('13', 'Rg'), ('萬', 'Rg'), ('至', 'p'), ('17', 'Rg'), ('萬', 'Rg'), ('人', 'n'), ('。', 'w'), ('而', 'c'), ('韓', 'Dg'), ('國', 'Ag'), ('自', 'p'), ('2020', 'Ng'), ('新', 'a'), ('冠', 'Ng'), ('肺炎', 'n'), ('疫', 'Dg'), ('情', 'n'), ('爆', 'v'), ('發', 'vd'), ('起', 'v'), ('，', 'w'), ('衛', 'o'), ('生局', 'o'), ('與', 'e'), ('生技', 'e'), ('公司', 'n'), ('合作', 'vn'), ('，', 'w'), ('不', 'd'), ('但', 'c'), ('加', 'v'), ('強', 'Rg'), ('實', 'Rg'), ('驗', 'Rg'), ('室', 'n'), ('的', 'u'), ('檢', 'Rg'), ('測量', 'Rg'), ('能', 'Ng'), ('、', 'w'), ('利用', 'v'), ('新', 'a'), ('技', 'Ng'), ('術', 'Dg'), ('追', 'v'), ('蹤', 'Dg'), ('可', 'v'), ('能', 'v'), ('接', 'v'), ('觸者', 'Tg'), ('儘', 'Tg'), ('早', 'Tg'), ('隔', 'v'), ('離', 'Tg'), ('，', 'w'), ('更', 'd'), ('透', 'v'), ('過', 'ns'), ('智慧', 'n'), ('型手', 'Rg'), ('機', 'Rg'), ('GPS', 'Rg'), ('定位', 'vn'), ('功', 'n'), ('能', 'v'), ('進', 'Mg'), ('行', 'a'), ('監', 'Ag'), ('測', 'Ng'), ('，', 'w'), ('派', 'v'), ('駐', 'Rg'), ('醫', 'Rg'), ('療', 'Rg'), ('人', 'n'), ('員', 'k'), ('前往', 'v'), ('患', 'v'), ('者', 'r'), ('住', 'v'), ('處', 'Rg'), ('進', 'Rg'), ('行治', 'Rg'), ('療', 'Rg'), ('，', 'w'), ('疫情', 'n'), ('也', 'd'), ('因此', 'c'), ('控制', 'v'), ('得宜', 'an'), ('。', 'w'), ('不', 'd'), ('過', 'v'), ('由', 'p'), ('於', 'Rg'), ('Omicron', 'Rg'), ('傳染', 'Rg'), ('力', 'n'), ('太', 'd'), ('過', 'Ag'), ('強', 'Bg'), ('大', 'a'), ('，', 'w'), ('確', 'Rg'), ('診者', 'Rg'), ('激增', 'v'), (' ...

# %% [markdown]
# # Q3:請挑一個本章節感興趣的NLP任務，使用SnowNLP或HaNLP完成。

# %%
s_t.summary()
# Out:
# ['Omicron大爆發扛不住 南韓宣布放棄檢測、追蹤輕症者',
#  '其中韓國自1月25日以來確診數日日破萬',
#  '韓國政府宣布放棄檢測及追蹤',
#  '政府也在7日宣布放棄檢測及追蹤輕症患者',
#  '將疫情控制得宜的南韓也不敵Omicron']
